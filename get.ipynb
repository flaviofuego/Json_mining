# %%
import pandas as pd
from dotenv import load_dotenv
import os
load_dotenv()
os.getenv("GOOGLE_APPLICATION_CREDENTIALS")
from pandas_gbq import read_gbq
query = """
SELECT *
FROM `mineria-msc.M9.tabla_base` 

"""
df = read_gbq(
    query,
    project_id="mineria-msc",
    dialect="standard",
    location="US"
)
df.head()
# Out:
# Downloading: 100%|██████████|
#   activityid                                       json_content
# 0      10002  {"activityid": 10002, "fields": {"Type": "Post...
# 1      10003  {"activityid": 10003, "fields": {"Type": "Pres...
# 2      10007  {"activityid": 10007, "fields": {"Type": "Pres...
# 3      10008  {"activityid": 10008, "fields": {"Type": "Pres...
# 4      10009  {"activityid": 10009, "fields": {"Type": "Pres...

# %%
df.shape
# Out:
# (42313, 2)
